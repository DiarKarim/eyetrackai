# %%
import cv2
import matplotlib.pyplot as plt 
import numpy as np

# %%
cap = cv2.VideoCapture("tmp/test.mp4")

# %%
ret, frame = cap.read()
frame
# Out:
# array([[[195, 133, 106],
#         [195, 133, 106],
#         [195, 133, 106],
#         ...,
#         [218, 155, 114],
#         [218, 155, 114],
#         [218, 155, 114]],
#
#        [[195, 133, 106],
#         [195, 133, 106],
#         [195, 133, 106],
#         ...,
#         [218, 155, 114],
#         [218, 155, 114],
#         [218, 155, 114]],
#
#        [[195, 133, 106],
#         [195, 133, 106],
#         [195, 133, 106],
#         ...,
#         [218, 156, 113],
#         [218, 156, 113],
#         [218, 156, 113]],
#
#        ...,
#
#        [[186, 127,  81],
#         [186, 127,  81],
#         [186, 127,  81],
#         ...,
#         [212, 157, 116],
#         [210, 155, 114],
#         [210, 155, 114]],
#
#        [[186, 127,  81],
#         [186, 127,  81],
#         [186, 127,  81],
#         ...,
#         [212, 157, 116],
#         [210, 155, 114],
#         [210, 155, 114]],
#
#        [[186, 127,  81],
#         [186, 127,  81],
#         [186, 127,  81],
# ...

# %%
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
# gray = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
gray_blurred = cv2.GaussianBlur(gray, (9, 9), 2, 2)
plt.imshow(gray_blurred)

# %%
circles = cv2.HoughCircles(gray_blurred, 
                           cv2.HOUGH_GRADIENT, 1, 50, 
                           param1=50, param2=30, minRadius=0, maxRadius=0)
circles
# Out:
# array([[[936.5, 429.5, 229.5]]], dtype=float32)

# %%
result = np.zeros(frame.shape)
if circles is not None:
    circles = np.uint16(np.around(circles))
    for i in circles[0, :]:
        # 绘制圆
        cv2.circle(result, (i[0], i[1]), i[2], (0, 255, 0), 2)
        # 绘制圆心
        cv2.circle(result, (i[0], i[1]), 2, (0, 0, 255), 3)

# %%
plt.imshow(result)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
red = frame.copy()
red[:2:]
# Out:
# array([[[203, 143, 110],
#         [204, 144, 111],
#         [205, 145, 112],
#         ...,
#         [221, 157, 112],
#         [221, 157, 112],
#         [221, 157, 112]],
#
#        [[205, 145, 112],
#         [207, 147, 114],
#         [207, 147, 114],
#         ...,
#         [221, 157, 112],
#         [221, 157, 112],
#         [221, 157, 112]]], dtype=uint8)

# %%
R, G, B = cv2.split(rgb)

# 现在R是红色通道，你可以直接使用R
# 如果你想在三通道图像格式中显示红色通道（其他通道为黑色），你可以这样做：
# red_channel_only = cv2.merge([R, G*0, B*0])

# 显示红色通道图像
plt.imshow(R)

# %%
R
# Out:
# array([[110, 111, 112, ..., 112, 112, 112],
#        [112, 114, 114, ..., 112, 112, 112],
#        [113, 114, 113, ..., 111, 111, 111],
#        ...,
#        [ 86,  86,  86, ..., 116, 116, 116],
#        [ 86,  86,  86, ..., 116, 116, 116],
#        [ 86,  86,  86, ..., 116, 116, 116]], dtype=uint8)

# %%
rgb = cv2.cvtColor(frame.copy(), cv2.COLOR_BGR2RGB)
plt.imshow(rgb)

# %%
rgb[450]
# Out:
# array([[101, 141, 199],
#        [100, 140, 198],
#        [ 99, 139, 197],
#        ...,
#        [112, 160, 218],
#        [111, 159, 217],
#        [110, 158, 216]], dtype=uint8)

# %%
import pandas as pd

# %%
pd.DataFrame()
